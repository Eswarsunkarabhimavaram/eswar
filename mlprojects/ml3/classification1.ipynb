# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
data=pd.read_csv("classificationloan.csv")
data
# Out:
#   Loan ID  No. of Dependencies     Education Self Employed Income/Annum (?)  \
# 0    L001                    0      Graduate            No         8,50,000
# 1    L002                    2      Graduate           Yes         6,20,000
# 2    L003                    3  Not Graduate            No         2,80,000
# 3    L004                    1      Graduate            No        12,00,000
# 4    L005                    4  Not Graduate           Yes         3,50,000
# 5    L006                    0      Graduate            No        15,00,000
# 6    L007                    2      Graduate            No         5,00,000
# 7    L008                    5  Not Graduate           Yes         2,20,000
# 8    L009                    1      Graduate           Yes         9,00,000
# 9    L010                    3  Not Graduate            No         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score residental_status  \
# ...

# %%
data.shape
# Out:
# (10, 13)

# %%
data.nunique()
# Out:
# Loan ID                10
# No. of Dependencies     6
# Education               2
# Self Employed           2
# Income/Annum (?)       10
# Loan Amount (?)         9
# Loan Term (Months)      5
# Credit Score           10
# residental_status      10
# commercial_assets       7
# luxury_assets          10
# bank_assets            10
# Loan Status             2
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_new= data.drop_duplicates(keep='first').reset_index(drop=True)
data_new
# Out:
#   Loan ID  No. of Dependencies     Education Self Employed Income/Annum (?)  \
# 0    L001                    0      Graduate            No         8,50,000
# 1    L002                    2      Graduate           Yes         6,20,000
# 2    L003                    3  Not Graduate            No         2,80,000
# 3    L004                    1      Graduate            No        12,00,000
# 4    L005                    4  Not Graduate           Yes         3,50,000
# 5    L006                    0      Graduate            No        15,00,000
# 6    L007                    2      Graduate            No         5,00,000
# 7    L008                    5  Not Graduate           Yes         2,20,000
# 8    L009                    1      Graduate           Yes         9,00,000
# 9    L010                    3  Not Graduate            No         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score residental_status  \
# ...

# %%
data_new.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data_new.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_new
# Out:
#   Loan ID  No. of Dependencies     Education Self Employed Income/Annum (?)  \
# 0    L001                    0      Graduate            No         8,50,000
# 1    L002                    2      Graduate           Yes         6,20,000
# 2    L003                    3  Not Graduate            No         2,80,000
# 3    L004                    1      Graduate            No        12,00,000
# 4    L005                    4  Not Graduate           Yes         3,50,000
# 5    L006                    0      Graduate            No        15,00,000
# 6    L007                    2      Graduate            No         5,00,000
# 7    L008                    5  Not Graduate           Yes         2,20,000
# 8    L009                    1      Graduate           Yes         9,00,000
# 9    L010                    3  Not Graduate            No         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score residental_status  \
# ...

# %%
data_new.columns
# Out:
# Index(['Loan ID', 'No. of Dependencies', 'Education', 'Self Employed',
#        'Income/Annum (?)', 'Loan Amount (?)', 'Loan Term (Months)',
#        'Credit Score', 'Residential Assets (?)', 'Commercial Assets (?)',
#        'Luxury Assets (?)', 'Bank Assets (?)', 'Loan Status'],
#       dtype='str')

# %%
data_new['total_assets_value']=data_new['residental_status']+data_new['commercial_assets']+data_new['luxury_assets']+data_new['bank_assets']
data_new
# Out:
#   Loan ID  No. of Dependencies     Education Self Employed Income/Annum (?)  \
# 0    L001                    0      Graduate            No         8,50,000
# 1    L002                    2      Graduate           Yes         6,20,000
# 2    L003                    3  Not Graduate            No         2,80,000
# 3    L004                    1      Graduate            No        12,00,000
# 4    L005                    4  Not Graduate           Yes         3,50,000
# 5    L006                    0      Graduate            No        15,00,000
# 6    L007                    2      Graduate            No         5,00,000
# 7    L008                    5  Not Graduate           Yes         2,20,000
# 8    L009                    1      Graduate           Yes         9,00,000
# 9    L010                    3  Not Graduate            No         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score residental_status  \
# ...

# %%
new=data_new.drop(columns=['residental_status','commercial_assets','luxury_assets','bank_assets'])
new
# Out:
#   Loan ID  No. of Dependencies     Education Self Employed Income/Annum (?)  \
# 0    L001                    0      Graduate            No         8,50,000
# 1    L002                    2      Graduate           Yes         6,20,000
# 2    L003                    3  Not Graduate            No         2,80,000
# 3    L004                    1      Graduate            No        12,00,000
# 4    L005                    4  Not Graduate           Yes         3,50,000
# 5    L006                    0      Graduate            No        15,00,000
# 6    L007                    2      Graduate            No         5,00,000
# 7    L008                    5  Not Graduate           Yes         2,20,000
# 8    L009                    1      Graduate           Yes         9,00,000
# 9    L010                    3  Not Graduate            No         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score Loan Status  \
# 0       15,00,000                 120           810    Approved
# ...

# %%
print(new.columns.tolist())
# Out:
# ['Loan ID', 'No. of Dependencies', 'Education', 'Self Employed', 'Income/Annum (?)', 'Loan Amount (?)', 'Loan Term (Months)', 'Credit Score', 'Loan Status', 'total_assets_value']

# %%
data_new
# Out:
#   Loan ID  No. of Dependencies     Education Self Employed Income/Annum (?)  \
# 0    L001                    0      Graduate            No         8,50,000
# 1    L002                    2      Graduate           Yes         6,20,000
# 2    L003                    3  Not Graduate            No         2,80,000
# 3    L004                    1      Graduate            No        12,00,000
# 4    L005                    4  Not Graduate           Yes         3,50,000
# 5    L006                    0      Graduate            No        15,00,000
# 6    L007                    2      Graduate            No         5,00,000
# 7    L008                    5  Not Graduate           Yes         2,20,000
# 8    L009                    1      Graduate           Yes         9,00,000
# 9    L010                    3  Not Graduate            No         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score Loan Status  \
# 0       15,00,000                 120           810    Approved
# ...

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
new['Education']=le.fit_transform(new['Education'])

# %%
new
# Out:
#   Loan ID  No. of Dependencies  Education Self Employed Income/Annum (?)  \
# 0    L001                    0          0            No         8,50,000
# 1    L002                    2          0           Yes         6,20,000
# 2    L003                    3          1            No         2,80,000
# 3    L004                    1          0            No        12,00,000
# 4    L005                    4          1           Yes         3,50,000
# 5    L006                    0          0            No        15,00,000
# 6    L007                    2          0            No         5,00,000
# 7    L008                    5          1           Yes         2,20,000
# 8    L009                    1          0           Yes         9,00,000
# 9    L010                    3          1            No         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score Loan Status  \
# 0       15,00,000                 120           810    Approved
# ...

# %%
new['Self Employed']=le.fit_transform(new['Self Employed'])
new['Loan Status']=le.fit_transform(new['Loan Status'])

# %%
new
# Out:
#   Loan ID  No. of Dependencies  Education  Self Employed Income/Annum (?)  \
# 0    L001                    0          0              0         8,50,000
# 1    L002                    2          0              1         6,20,000
# 2    L003                    3          1              0         2,80,000
# 3    L004                    1          0              0        12,00,000
# 4    L005                    4          1              1         3,50,000
# 5    L006                    0          0              0        15,00,000
# 6    L007                    2          0              0         5,00,000
# 7    L008                    5          1              1         2,20,000
# 8    L009                    1          0              1         9,00,000
# 9    L010                    3          1              0         3,80,000
#
#   Loan Amount (?)  Loan Term (Months)  Credit Score  Loan Status  \
# 0       15,00,000                 120           810            0
# ...

# %%
new.isnull().values.any()
# Out:
# np.False_

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
new['Income/Annum (?)'] = (
    new['Income/Annum (?)']
    .str.replace(',', '')
    .astype(float)
)

new['Income/Annum (?)'] = np.log(new['Income/Annum (?)'])

# %%
new['Loan Amount (?)'] = np.log(new['Loan Amount (?)'])

# %%
new['total_assets_value'] = (
    new['total_assets_value']
    .str.replace(',', '')
    .astype(float)
)

new['total_assets_value'] = np.log(new['total_assets_value'])

# %%
new
# Out:
#   Loan ID  No. of Dependencies  Education  Self Employed  Income/Annum (?)  \
# 0    L001                    0          0              0         13.652992
# 1    L002                    2          0              1         13.337475
# 2    L003                    3          1              0         12.542545
# 3    L004                    1          0              0         13.997832
# 4    L005                    4          1              1         12.765688
# 5    L006                    0          0              0         14.220976
# 6    L007                    2          0              0         13.122363
# 7    L008                    5          1              1         12.301383
# 8    L009                    1          0              1         13.710150
# 9    L010                    3          1              0         12.847927
#
#    Loan Amount (?)  Loan Term (Months)  Credit Score  Loan Status  \
# 0         2.654718                 120           810            0
# ...

# %%
X=new.drop(columns=['Loan Status','Loan ID'])

# %%
X
# Out:
#    No. of Dependencies  Education  Self Employed  Income/Annum (?)  \
# 0                    0          0              0         13.652992
# 1                    2          0              1         13.337475
# 2                    3          1              0         12.542545
# 3                    1          0              0         13.997832
# 4                    4          1              1         12.765688
# 5                    0          0              0         14.220976
# 6                    2          0              0         13.122363
# 7                    5          1              1         12.301383
# 8                    1          0              1         13.710150
# 9                    3          1              0         12.847927
#
#    Loan Amount (?)  Loan Term (Months)  Credit Score  total_assets_value
# 0         2.654718                 120           810           44.665408
# 1         2.667457                 180           760           55.849829
# ...

# %%
Y=new['Loan Status']

# %%
Y
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# 5    0
# 6    0
# 7    1
# 8    0
# 9    1
# Name: Loan Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (8, 8)

# %%
x_test.shape
# Out:
# (2, 8)

# %%
from sklearn.linear_model import LogisticRegression
lg_model = LogisticRegression(max_iter=2000, penalty='l2')

# %%
model = lg_model.fit(x_train, y_train)
# Out:
# C:\Users\Easwar\AppData\Roaming\Python\Python311\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(

# %%
model
# Out:
# LogisticRegression(max_iter=2000, penalty='l2')

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0])
